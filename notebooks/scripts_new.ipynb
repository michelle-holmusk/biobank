# %% [markdown]
# # Packages

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import re
# %matplotlib inline

# %% [markdown]
# # Dataset

# %%
#prescription from primary care data
scripts = pd.read_csv('../primary_care/gp_scripts.txt', sep = '\t', encoding='ISO-8859-1')

# %%
# previous dataset",
records = pd.read_pickle('../primary_care/full_records.pkl')

# %%
#bayer prescriptions
prescriptions = pd.read_excel('../primary_care/prescriptions.xlsx')

# %%
#drug encodings
drug_lkps = pd.read_excel('../primary_care/all_lkps_maps.xlsx', sheet_name='read_v2_drugs_lkp')

# %%
records
# Out:
#            eid                                              coded  \
# 0      1000255                           [[02/09/2015, cad, sec]]
# 1      1000421  [[04/08/2010, cad, sec], [27/05/2010, stroke, ...
# 2      1000466                           [[11/06/2002, cad, sec]]
# 3      1000584  [[16/06/1997, cad, sec], [19/10/2004, afib, sec]]
# 4      1000674                           [[31/05/2006, cad, sec]]
# ...        ...                                                ...
# 53318  6020725                                                 []
# 53319  6021009                                                 []
# 53320  6021143                                                 []
# 53321  6022795                                                 []
# 53322  6023090                                                 []
#
#                                            data_provider  \
# 0                                                    NaN
# 1                                                 [3, 3]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                                             [3, 3]
# 53319                                                [3]
# 53320  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# 53321                                                [2]
# 53322                                                [3]
#
#                                                 event_dt  \
# 0                                                    NaN
# 1                               [27/05/2010, 04/10/2010]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                           [01/01/1993, 18/09/2003]
# 53319                                       [09/06/2016]
# 53320  [20/01/2005, 11/02/2005, 07/04/2005, 21/11/200...
# 53321                                       [19/01/2015]
# 53322                                       [29/07/2005]
#
#                                                   read_2  \
# 0                                                    NaN
# 1                                             [nan, nan]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                                         [nan, nan]
# 53319                                              [nan]
# 53320  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 53321                                            [G5730]
# 53322                                              [nan]
#
#                                                   read_3  \
# 0                                                    NaN
# 1                                         [XE0VK, XE2uV]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                                     [G66.., XE0VK]
# 53319                                            [G5730]
# 53320  [X00DW, X00DW, X00DW, X00DW, X00DW, X00DW, X00...
# 53321                                              [nan]
# 53322                                            [XE2uV]
#
#                                                   value1  \
# 0                                                    NaN
# 1                                             [nan, nan]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                                         [nan, nan]
# 53319                                              [nan]
# 53320  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 53321                                              [nan]
# 53322                                              [nan]
#
#                                                   value2  \
# 0                                                    NaN
# 1                                             [nan, nan]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                                         [nan, nan]
# 53319                                              [nan]
# 53320  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 53321                                              [nan]
# 53322                                              [nan]
#
#                                                   value3  \
# 0                                                    NaN
# 1                                             [nan, nan]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                                         [nan, nan]
# 53319                                              [nan]
# 53320  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 53321                                              [nan]
# 53322                                              [nan]
#
#                                                condition  ... first_record_d  \
# 0                                                    NaN  ...     2015-09-02
# 1                                             [TIA, CAD]  ...     2010-05-27
# 2                                                    NaN  ...     2002-06-11
# 3                                                    NaN  ...     1997-06-16
# 4                                                    NaN  ...     2006-05-31
# ...                                                  ...  ...            ...
# 53318                                      [Stroke, TIA]  ...     1993-01-01
# 53319                                             [Afib]  ...     2016-06-09
# 53320  [TIA, TIA, TIA, TIA, TIA, TIA, TIA, TIA, TIA, ...  ...     2005-01-20
# 53321                                             [Afib]  ...     2015-01-19
# 53322                                              [CAD]  ...     2005-07-29
#
#       first_record_diag  first_stroke_after_d first_stroke_type  \
# 0                   cad                   NaT               NaN
# 1                   tia            2010-05-27            stroke
# 2                   cad                   NaT               NaN
# 3                   cad                   NaT               NaN
# 4                   cad                   NaT               NaN
# ...                 ...                   ...               ...
# 53318            stroke            2003-09-18               tia
# 53319              afib                   NaT               NaN
# 53320               tia            2005-02-11               tia
# 53321              afib                   NaT               NaN
# 53322               cad                   NaT               NaN
#
#                                                      pri  \
# 0                                                     []
# 1      [[2010-05-27 00:00:00, tia, pri], [2010-10-04 ...
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 53318  [[1993-01-01 00:00:00, stroke, pri], [2003-09-...
# 53319                 [[2016-06-09 00:00:00, afib, pri]]
# 53320  [[2005-01-20 00:00:00, tia, pri], [2005-02-11 ...
# 53321                 [[2015-01-19 00:00:00, afib, pri]]
# 53322                  [[2005-07-29 00:00:00, cad, pri]]
#
#                                                      sec discrepancy  \
# 0                      [[2015-09-02 00:00:00, cad, sec]]       False
# 1      [[2010-05-27 00:00:00, stroke, sec], [2010-08-...       False
# 2                      [[2002-06-11 00:00:00, cad, sec]]       False
# 3      [[1997-06-16 00:00:00, cad, sec], [2004-10-19 ...       False
# 4                      [[2006-05-31 00:00:00, cad, sec]]       False
# ...                                                  ...         ...
# 53318                                                 []       False
# 53319                                                 []       False
# 53320                                                 []       False
# 53321                                                 []       False
# 53322                                                 []       False
#
#       noRecords noRecords2   event_int
# 0             1          1         NaN
# 1             4          4    0.000000
# 2             1          1         NaN
# 3             2          2         NaN
# 4             1          1         NaN
# ...         ...        ...         ...
# 53318         2          2  128.528307
# 53319         1          1         NaN
# 53320        19         19    0.722807
# 53321         1          1         NaN
# 53322         1          1         NaN
#
# [53323 rows x 27 columns]

# %% [markdown]
# # Prescriptions

# %%
prescriptions.columns = ['Antidiabetes', 'Antihyperlipidemic', 'Antihypertensive']

# %%
prescription_name = {
    'antidiabetes' : {
        'names': list(prescriptions['Antidiabetes'][:15])
    },
    'antihyperlipidemic' : {
        'names': list(prescriptions['Antihyperlipidemic'][:6])
    },
    'antihypertensive' : {
        'names': list(prescriptions['Antihypertensive'].values)
    }, 
    'all' : {
        'names': list(prescriptions['Antidiabetes'][:15])+ list(prescriptions['Antihyperlipidemic'][:6]) + list(prescriptions['Antihypertensive'].values)
    }
}

# %% [markdown]
# # patients

# %%
patients = list(records['eid'])

# %%
len(patients)
# Out:
# 53323

# %%
relevant_scripts = scripts[scripts['eid'].isin(patients)].reset_index()

# %%
relevant_scripts.shape
# Out:
# (17036267, 9)

# %%
relevant_scripts.columns
# Out:
# Index(['index', 'eid', 'data_provider', 'issue_date', 'read_2', 'bnf_code',
#        'dmd_code', 'drug_name', 'quantity'],
#       dtype='object')

# %%
concise_scripts = relevant_scripts[['eid', 'read_2', 'bnf_code', 'dmd_code', 'drug_name', 'quantity']]

# %%
concise_scripts['drug_name'] = concise_scripts['drug_name'].str.lower()
# Out:
# /Users/michelleng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
prescriptions = list(relevant_scripts.drug_name.unique())

# %%
prescriptions_clean = [x.replace("*", "") for x in prescriptions if type(x) == str]

# %%
ointments = []
oral = []
intravenous = []
optha = []
ENT = []
equipment = []
alternative = []
supplements = []
unknown = []
accessories = ['bag', 'stocking', 'catheter', 'stockinette', 
               'dressing', 'suture', 'test', 'tape', 'bandage',
              'swab', 'syringe', 'needle', 'ostomy']
transdermal = ['injection', 'vaccine', 'hypodermic', 'inj']
nasal = ['inhaler', 'nasal spray', 'ear', 'inhalation', 'inh']
dermal = ['oint', 'ointment', 'cream', 'lotion', 'crm', 'dermal', 
          'shampoo', 'wash', 'spray', 'patches', 'gel', 
          'emollient', 'derm']
supplement = ['shake', 'supplement', 'supplemental', 'vitamin']
ingest = ['tabs', 'tablets', 'tab', 'cap','caps', 'capsule', 'oral']
suppository = ['suppository', 'pessary', 'rectal']
for x in prescriptions_clean: 
    if type(x) == float: 
        continue
    elif any(i in x for i in ingest):
        oral.append(x)
    elif any(n in x for n in nasal):
        ENT.append(x)
    elif any(d in x for d in dermal):
        ointments.append(x)
    elif any(t in x for t in transdermal):
        intravenous.append(x)
    elif 'eye' in x:
        optha.append(x)
    elif any(a in x for a in accessories):
        equipment.append(x)
    elif any(su in x for su in supplement):
        supplements.append(x)
    elif any(s in x for s in suppository):
        alternative.append(x)
    else:
        unknown.append(x)

# %%
dfnames= ['ENT','ointments', 'intravenous', 'optha', 'equipment', 'oral', 'alternative','supplements', 'unknown']

# %%
dfs = [ENT, ointments, intravenous, optha, equipment, oral, alternative, supplements, unknown]

# %%
combined = pd.DataFrame(columns = ['prescription', 'proposedcategory'])
def dfmaker(dflist, dfnamelist, resultdf):
    for i in range(len(dflist)):
        temp = pd.DataFrame(dflist[i], columns = ['prescription'])
        temp['proposedcategory'] = dfnamelist[i]
        resultdf = resultdf.append(temp)
    return resultdf

# %%
combined = dfmaker(dfs, dfnames, combined)

# %%
a = list(combined.prescription.unique())

# %%
[elem for elem in prescriptions_clean if elem not in a ]

# %%
combined.shape

# %%
combined['group'] = [x.split(" ")[0] if type(x.split(" ")[0]) == str else np.nan for x in combined['prescription']]

# %%
len(combined.group.unique())

# %%
combined.groupby('group').agg(list)

# %%
combined_arranged = combined[['group', 'prescription', 'proposedcategory']]

# %%
combined_arranged.to_csv('../primary_care/unique_medications.csv')

# %%
oralmed = combined[combined['proposedcategory'] == 'oral']

# %%
oralmed.groupby('group').agg(list)

# %%
list(combined.group.unique())
# Out:
# ['flixonase',
#  'betnesol-n',
#  'fluticasone',
#  'gentisone',
#  'sterimar',
#  'salbutamol',
#  'becotide',
#  'beclometasone',
#  'heliclear',
#  'qvar',
#  'salamol',
#  'olive',
#  'cerumol',
#  'sofradex',
#  'beconase',
#  'sodium',
#  'mometasone',
#  'ventolin',
#  'beclazone',
#  'betamethasone',
#  'clenil',
#  'flutiform',
#  'flumetasone',
#  'otomize',
#  'locorten',
#  'ciprofloxacin',
#  'liquifilm',
#  'gentamicin',
#  'triamcinolone',
#  'ipratropium',
#  'budesonide',
#  'xylometazoline',
#  'rinatec',
#  'pelican',
#  'betnesol',
#  'nasonex',
#  'terbutaline',
#  'serevent',
#  'salmeterol',
#  'avamys',
#  'otosporin',
#  'atrovent',
#  'viscotears',
#  'hylo-tear',
#  'nicotine',
#  'docusate',
#  'urea',
#  'nicorette',
#  'earcalm',
#  'geltears',
#  'acetic',
#  'tears',
#  'symbicort',
#  'fostair',
#  'carmellose',
#  'sumatriptan',
#  'niquitin',
#  'azelastine',
#  'becloforte',
#  'chloramphenicol',
#  'dexamethasone',
#  'clear',
#  'rhinolast',
#  'libra',
#  'jade',
#  'gb',
#  'locorten-vioform',
#  'sterile',
#  'gb3',
#  'audicort',
#  'beclomethasone',
#  'minims',
#  'neomycin',
#  'combivent',
#  'aclidinium',
#  'zolmitriptan',
#  'easyhaler',
#  'gb4',
#  'asmanex',
#  'airomir',
#  'sirdupla',
#  'nova',
#  'flixotide',
#  'clioquinol',
#  'genticin',
#  'formoterol',
#  'menthol',
#  'prednisolone',
#  'ventolin-p42',
#  'seretide',
#  'dymista',
#  'relvar',
#  'tiotropium',
#  'anoro',
#  'spiriva',
#  'predsol',
#  'otex',
#  'flunisolide',
#  'nasacort',
#  'waxsol',
#  'bricanyl',
#  'lyclear',
#  'sno',
#  'rhinocort',
#  'exterol',
#  'almond',
#  'ciclesonide',
#  'beclo-aqua',
#  'desmopressin',
#  'pulmicort',
#  'syntaris',
#  'duoresp',
#  'dexa-rhinaspray',
#  'alvesco',
#  'otovent',
#  'resource',
#  'vibrocil',
#  'incruse',
#  'nasofan',
#  'otrivine',
#  'becloforte-p42',
#  'sofradex-p42',
#  'beconase-p42',
#  'nedocromil',
#  'rynacrom',
#  'nasobec',
#  'umeclidinium',
#  'vistamethasone',
#  'neo-cortef',
#  'salbulin',
#  'airflusal',
#  'hypotears',
#  'aerodiol',
#  'nutilis',
#  'vista-methasone',
#  'gb3s',
#  'tramazoline',
#  'blink',
#  'assura',
#  'predsol-n',
#  'atimos',
#  'unique',
#  'aerobec',
#  'aerolin',
#  'asmasal',
#  'asmabec',
#  'nafarelin',
#  'salbutamol-p42',
#  'cromogen',
#  'oxivent',
#  'buserelin',
#  'hydrogen',
#  'terra-cortril',
#  'ventide',
#  'cuiwear',
#  'intal',
#  'gel',
#  'thick',
#  'chloromycetin',
#  'triadcortyl',
#  'ipratrop.',
#  'imigran',
#  'filair',
#  'moderma',
#  'swalloweze',
#  'sno-tears',
#  'lubri-tears',
#  'glyceryl',
#  'miacalcic',
#  'fortijuce',
#  'becotide-p42',
#  'oxitropium',
#  'welland',
#  'nebusal',
#  'aerocrom',
#  'clearpore',
#  'sensura',
#  'zomig',
#  'preparation',
#  'syntaris-p42',
#  'trachi-naze',
#  'spirotect',
#  'fentanyl',
#  'tegaderm',
#  'dermovate',
#  'evorel',
#  'miconazole',
#  'betnovate-n',
#  'diclofenac',
#  'daktacort',
#  'canesten',
#  'lacri-lube',
#  'clinitas',
#  'epaderm',
#  'ibuprofen',
#  'scheriproct',
#  'nystaform',
#  'timodine',
#  'fucidin',
#  'clotrimazole',
#  'anusol',
#  'hydrocortisone',
#  'trimovate',
#  'piroxicam',
#  'diprobase',
#  'fusidic',
#  'instillagel',
#  'duoderm',
#  'cavilon',
#  'mupirocin',
#  'white',
#  'fucibet',
#  'aqueous',
#  'nicotinell',
#  'flamazine',
#  'aquaform',
#  'doublebase',
#  'naseptin',
#  'aveeno',
#  'clobetasone',
#  'ingenol',
#  'fluorouracil',
#  'buprenorphine',
#  'oilatum',
#  'chlorhexidine',
#  'voltarol',
#  'glucorx',
#  'estriol',
#  'hydromol',
#  'terbinafine',
#  'movelat',
#  'ketoconazole',
#  'fenbid',
#  'eumovate',
#  'coro-nitro',
#  'algesal',
#  'calmurid',
#  'fybogel',
#  'solaraze',
#  'dermol',
#  'pilogel',
#  'polyfax',
#  'benzydamine',
#  'efudix',
#  'proctosedyl',
#  'tri-adcortyl',
#  'nitrolingual',
#  'calcipotriol',
#  'dithrocream',
#  'dovobet',
#  'felbinac',
#  'lipobase',
#  'bactroban',
#  'emulsifying',
#  'transvasin',
#  'bd',
#  'disposal',
#  'testogel',
#  'nitromin',
#  'betnovate',
#  'omnican',
#  'clobetasol',
#  'ortho-gynest',
#  'diethylamine',
#  'fluocinolone',
#  'gynest',
#  'aciclovir',
#  'estradiol',
#  'estraderm',
#  'testosterone',
#  'calamine',
#  'stericlens',
#  'artificial',
#  'lubri-sil',
#  'sorbaderm',
#  'hydrous',
#  'eurax',
#  'permethrin',
#  'rectogesic',
#  'aureocort',
#  'dansac',
#  'alphosyl',
#  'zovirax',
#  'vita-pos',
#  'hypodermic',
#  'novofine',
#  'cinchocaine',
#  'crotamiton',
#  'kentera',
#  'ovestin',
#  'zeroderm',
#  'coal',
#  'sebco',
#  'mucogel',
#  'dermacolor',
#  'xyloproct',
#  'e45',
#  'intrasite',
#  'ibugel',
#  'clindamycin',
#  'dalacin',
#  'unguentum',
#  'zerobase',
#  'ultraproct',
#  'durogesic',
#  'butrans',
#  'transtec',
#  'traxam',
#  'saliveze',
#  'loceryl',
#  'diprosalic',
#  'ketoprofen',
#  'hirudoid',
#  'salatac',
#  'sunsense',
#  'powergel',
#  'cetraben',
#  'synalar',
#  'eczmol',
#  'salicylic',
#  'emulsiderm',
#  'locoid',
#  'elocon',
#  'tacrolimus',
#  'propaderm',
#  'bazuka',
#  'cocois',
#  'hyoscine',
#  'sudocrem',
#  'anusol-hc',
#  'conotrane',
#  'germoloids',
#  'metronidazole',
#  'mylife',
#  'zineryt',
#  'dovonex',
#  'meted',
#  'dermax',
#  'emollin',
#  'irriclens',
#  'ortho',
#  'adcortyl',
#  'verrugon',
#  'fludroxycortide',
#  'tretinoin',
#  'dibrompropamidine',
#  'kolanticon',
#  'micanol',
#  'econacort',
#  'xailin',
#  'metrogel',
#  'carbomer',
#  'balneum',
#  'rozex',
#  'podophyllotoxin',
#  'emla',
#  'glandosane',
#  'feldene',
#  'proflex',
#  'diprobath',
#  'metosyn',
#  't-gel',
#  'cuplex',
#  'matrifen',
#  'selenium',
#  'selsun',
#  'heparinoid',
#  'ecostatin',
#  'zerocream',
#  'liquid',
#  'novopen',
#  'optipen',
#  'iodosorb',
#  'aderma',
#  'sulfadiazine',
#  'zinc',
#  'polytar',
#  'anugesic-hc',
#  'rotigotine',
#  'corsodyl',
#  'siopel',
#  'benzalkonium',
#  'protopic',
#  'gyno-pevaryl',
#  'salactol',
#  'medihoney',
#  'eucerin',
#  'phorpain',
#  'azelaic',
#  'chiron',
#  'comfeel',
#  'povidone-iodine',
#  'carepoint',
#  'hydrogel',
#  'fluocinonide',
#  'oxybutynin',
#  'lidocaine',
#  'conjugated',
#  'buscopan',
#  'ibuleve',
#  'mucopolysaccharide',
#  'vioform',
#  'lotriderm',
#  'alphaderm',
#  'betnovate-c',
#  'isopropyl',
#  'nuvelle',
#  'unifine',
#  'chlortetracycline',
#  'activheal',
#  'ultrabase',
#  't/gel',
#  'loprofin',
#  'glytrin',
#  'difflam',
#  'doxepin',
#  'zerodouble',
#  'cutivate',
#  'dermasilk',
#  'curatoderm',
#  'xamiol',
#  'daktarin',
#  'qv',
#  't',
#  'exorex',
#  'intralgin',
#  'balmosa',
#  'ralgex',
#  'deep',
#  'bioxtra',
#  'stiedex',
#  'exelderm',
#  'ivermectin',
#  'ostomist',
#  'ostomart',
#  'formaldehyde',
#  'posalfilin',
#  'octenisan',
#  'hypostop',
#  'autopen',
#  'glucogel',
#  'rivastigmine',
#  'exelon',
#  'nerisone',
#  'efcortelan',
#  'haelan',
#  'biocath',
#  'nystaform-hc',
#  'oruvail',
#  'gyno-daktarin',
#  'choline',
#  'salicylates',
#  'nystatin',
#  'aureomycin',
#  'betadine',
#  'metanium',
#  'rinstead',
#  'cicatrin',
#  'lumecare',
#  'bonjela',
#  'lamisil',
#  'silver',
#  'clinimed',
#  'kliniderm',
#  'opus',
#  'benzamycin',
#  'epimax',
#  'vioform-hydrocortisone',
#  'vismed',
#  'maxitrol',
#  'sympacath',
#  'oestrogel',
#  'aquadrate',
#  'zeroaqs',
#  'flexitol',
#  'insupen',
#  'psoriderm',
#  'oilatium',
#  'citrus',
#  'dermatonics',
#  'estracombi',
#  'humapen',
#  'silicone',
#  'amorolfine',
#  'uniroid',
#  'aserbine',
#  'polymyxin',
#  'econazole',
#  'clinitar',
#  'premarin',
#  'erythromycin',
#  'peel-easy',
#  'carbenoxolone',
#  'allergenics',
#  'limone',
#  'skinsafe',
#  'absorbagel',
#  'cohesive',
#  'xylocaine',
#  'microlance',
#  'anabact',
#  'isotretinoin',
#  'perinal',
#  'nurofen',
#  'roc',
#  'ccs',
#  'uvistat',
#  'biotene',
#  'halciderm',
#  'neutrogena',
#  'sulfur',
#  'elidel',
#  'flaminal',
#  'difflam-p',
#  'testim',
#  'calcitriol',
#  'diprosone',
#  'alupent',
#  'genisol',
#  'mildison',
#  'dermacool',
#  'cetomacrogol',
#  'aquamax',
#  'dienestrol',
#  'hexetidine',
#  'duragel',
#  'ortho-creme',
#  'gygel',
#  'brava',
#  'salts',
#  'bard',
#  'naturcare',
#  'malathion',
#  'xepin',
#  'coconut',
#  'eludril',
#  'colgate',
#  'mepyramine',
#  'brimonidine',
#  'xerotin',
#  'lacrilube',
#  'as',
#  'axsain',
#  'dioderm',
#  'cutimed',
#  'kelo-cote',
#  'carbo-dome',
#  'femseven',
#  'halcinonide',
#  'zacin',
#  'keromask',
#  'savlon',
#  'anhydrol',
#  'whitfields',
#  'ciloxan',
#  'modrasone',
#  'picato',
#  'dermacol',
#  'sultrin',
#  'eumocream',
#  'osmanil',
#  'fencino',
#  'timoptol-la',
#  'dimeticone',
#  'oily',
#  'drapolene',
#  'simple',
#  'alclometasone',
#  'imiquimod',
#  'etrivex',
#  'ispagel',
#  'nupercainal',
#  'clikstar',
#  'diflucortolone',
#  'ibuspray',
#  'diltiazem',
#  'covermark',
#  'freshaire',
#  'mezolar',
#  'cetrimide',
#  'ciclosporin',
#  'quellada',
#  'nystan',
#  'aquagel',
#  'canesten-p42',
#  'pimecrolimus',
#  'andropatch',
#  'aldara',
#  'scopoderm',
#  'benzoyl',
#  'glutarol',
#  'adapalene',
#  'nu-gel',
#  'sun',
#  'proshield',
#  'emollient',
#  'fematrix',
#  'sulconazole',
#  'salicylamide',
#  'mirvaso',
#  'lasonil',
#  'cetavlex',
#  'dithranol',
#  'benzocaine',
#  'syringe',
#  'monoject',
#  'friends',
#  'tricicatrin',
#  '3m',
#  'wipeaway',
#  'liqua',
#  'quinocort',
#  'varimate',
#  'dextrogel',
#  'granisetron',
#  'anugesic',
#  'gtn',
#  'tolnaftate',
#  'rhus',
#  'arnica',
#  'tetracaine',
#  'myribase',
#  'eflornithine',
#  'finacea',
#  'oestradiol',
#  'mycota',
#  'duac',
#  'quinoderm',
#  'eurax-hydrocortisone',
#  'hedrin',
#  'keri',
#  'zidoval',
#  'balance',
#  'acnegel',
#  'retin-a',
#  'bepanthen',
#  'titanium',
#  'prioderm',
#  'elleste',
#  'alprostadil',
#  'tazarotene',
#  'anthisan',
#  'comfort',
#  'cadexomer',
#  'artelac',
#  'anacal',
#  'aaa',
#  'transiderm-nitro',
#  'lavera',
#  'clinifilm',
#  'dermovate-nn',
#  'derma-gard',
#  'peppermint',
#  'blephasol',
#  'neupro',
#  'tacalcitol',
#  'thymol',
#  'opticlik',
#  'dulcolax',
#  'medi',
#  'veil',
#  'methyl',
#  'bioplex',
#  'onetouch',
#  'opsite',
#  'ichthammol',
#  'prontosan',
#  'anbesol',
#  'purilon',
#  'geliperm',
#  'isotrex',
#  'lemon',
#  'dextrose',
#  'washable',
#  'butec',
#  'tostran',
#  'novotwist',
#  'optilube',
#  'fifty:50',
#  'ceanel',
#  'xerostom',
#  'penciclovir',
#  'betnovate-rd',
#  'hollister',
#  'zyclara',
#  'vapour-permeable',
#  'panoxyl',
#  'scarsil',
#  'blistex',
#  'suleo-m',
#  'progynova',
#  'iq',
#  'intrinsa',
#  'polycrol',
#  'flurandrenolone',
#  'curanail',
#  'penfine',
#  'orajel',
#  'spirigel',
#  'liquivisc',
#  'convatec',
#  'vectavir',
#  'wool',
#  'clarelux',
#  'differin',
#  'iglu',
#  'granugel',
#  'lpl',
#  'ametop',
#  'tricare',
#  'lignocaine',
#  'lidoderm',
#  'glycerol',
#  'elite',
#  'timolol',
#  'silgel',
#  'dienoestrol',
#  'betnovate-p42',
#  'lift',
#  'timoptol',
#  'actiformcool',
#  'mycil',
#  'one',
#  'acea',
#  'nitro-dur',
#  'estradot',
#  'silkis',
#  'relactagel',
#  'povidone',
#  'coloplast',
#  'buffered',
#  'atmocol',
#  'eumobase',
#  'mesitran',
#  'retinova',
#  'isogel',
#  'bioderm',
#  'lbf',
#  'dermatix',
#  'gelorevoice',
#  'treclin',
#  'clobet',
#  'eryacne',
#  'lubricating',
#  'desoximetasone',
#  'shark',
#  'vernagel',
#  'crystacide',
#  'aquamol',
#  'h',
#  'blephagel',
#  'zovirax-2g',
#  'systane',
#  'graneodin',
#  'zeroguent',
#  'lindane',
#  'somatuline',
#  'deponit',
#  'hyperseal',
#  'optrex',
#  'provox',
#  'psorin',
#  'pen',
#  'isomol',
#  'nicotinamide',
#  'opticrom',
#  'iodoflex',
#  'cetaphil',
#  'typherix',
#  'epaxal',
#  'typhim',
#  'influenza',
#  'pneumovax',
#  'revaxis',
#  'fluarix',
#  'viatim',
#  'depo-medrone',
#  'marcain',
#  'methylprednisolone',
#  'tetavax',
#  'liraglutide',
#  'hydroxocobalamin',
#  'immunoglobulin',
#  'begrivac',
#  'influvac',
#  'havrix',
#  'clostet',
#  'diphtheria',
#  'mastaflu',
#  'pandemrix',
#  'ergocalciferol',
#  'tinzaparin',
#  'metoclopramide',
#  'humulin',
#  'mfv-ject',
#  'imuvac',
#  'vaqta',
#  'epipen',
#  'kenalog',
#  'enoxaparin',
#  'fluvirin',
#  'levomepromazine',
#  'diamorphine',
#  'midazolam',
#  'water',
#  'morphine',
#  'enzira',
#  'zostavax',
#  'avaxim',
#  'rexocaine',
#  'hepatyrix',
#  'leuprorelin',
#  'agrippal',
#  'intanza',
#  'bydureon',
#  'arilvax',
#  'sterets',
#  'kabiglobulin',
#  'gammabulin',
#  'tetanus',
#  'etanercept',
#  'adsorbed',
#  'engerix',
#  'diftavax',
#  'hepatitis',
#  'oxycodone',
#  'poliomyelitis',
#  'typhoid',
#  'novomix',
#  'haloperidol',
#  'mixtard',
#  'twinrix',
#  'mengivac',
#  'actrapid',
#  'ultratard',
#  'novorapid',
#  'lantus',
#  'levemir',
#  'invivac',
#  'exenatide',
#  'prostap',
#  'heparin',
#  'apo-go',
#  'pneumococcal',
#  'viroflu',
#  'lignospan',
#  'methylprednisolone/l',
#  'methylprednisolone/lignocaine',
#  'human',
#  'glucagen',
#  'humalog',
#  'fragmin',
#  'dalteparin',
#  'glucagon',
#  'rabies',
#  'shingles',
#  'hbvaxpro',
#  'meriux',
#  'meningococcal',
#  'cholera',
#  'insulin',
#  'citanest',
#  'cyclizine',
#  'glycopyrronium',
#  'scandonest',
#  'insulatard',
#  'adalimumab',
#  'filgrastim',
#  'byetta',
#  'caverject',
#  'degarelix',
#  'victoza',
#  'anapen',
#  'firmagon',
#  'nebido',
#  'stamaril',
#  'triptorelin',
#  'yellow',
#  'acwy',
#  'nimenrix',
#  'octreotide',
#  'ixiaro',
#  'japanese',
#  'clexane',
#  'depixol',
#  'viridal',
#  'cyanocobalamin',
#  'ac',
#  'inflexal',
#  'lanreotide',
#  'prochlorperazine',
#  'metoject',
#  'methotrexate',
#  'adrenaline',
#  'normal',
#  'aranesp',
#  'fendrix',
#  'apidra',
#  'glucagon(rys)',
#  'depomedrone',
#  'menveo',
#  'konakion',
#  'bexsero',
#  'haemophilus',
#  'velosulin',
#  'h-b-vax',
#  'stemetil',
#  'penmix',
#  'lederspan',
#  'sustanon',
#  'pork',
#  'epinephrine',
#  'hypurin',
#  'rabipur',
#  'abatacept',
#  'jext',
#  'monotard',
#  'insuman',
#  'trulicity',
#  'fluzone',
#  'toujeo',
#  'largactil',
#  'ostenil',
#  'synovial',
#  'cosmofer',
#  'gamma',
#  'iron',
#  'calciferol',
#  'epilim',
#  'lixisenatide',
#  'methylnaltrexone',
#  'dulaglutide',
#  'nozinan',
#  'ketorolac',
#  'phytomenadione',
#  'lorazepam',
#  'efcortesol',
#  'darbepoetin',
#  'humaject',
#  'abasaglar',
#  'cyclimorph',
#  'baclofen',
#  'inactivated',
#  'hb-vax',
#  'maxolon',
#  'repevax',
#  'epoetin',
#  'co-trimoxazole',
#  'jectofer',
#  'medroxyprogesterone',
#  'colistimethate',
#  'colomycin',
#  'emerade',
#  'depo-provera',
#  'min-i-jet',
#  'alfentanil',
#  'neorecormon',
#  'neo-cytamen',
#  'faslodex',
#  'depo-med+lidoc',
#  'chlorphenamine',
#  'xultophy',
#  'myocrisin',
#  'humatrope',
#  'solu-cortef',
#  'furosemide',
#  'pnu-imune',
#  'primoteston',
#  'tet/vac/ads',
#  'priorix',
#  'teriparatide',
#  'tresiba',
#  'meningitec',
#  'chorionic',
#  'pergonal',
#  'fucithalmic',
#  'hypromellose',
#  'polyvinyl',
#  'travatan',
#  'latanoprost',
#  'duotrav',
#  'monopost',
#  'teoptic',
#  'xalacom',
#  'isopto',
#  'lodoxamide',
#  'xalatan',
#  'lumigan',
#  'azopt',
#  'alphagan',
#  'golden',
#  'combigan',
#  'brinzolamide',
#  'pilocarpine',
#  'pred',
#  'atropine',
#  'dorzolamide',
#  'cosopt',
#  'bimatoprost',
#  'cyclopentolate',
#  ...]

# %%
relevant_scripts
# Out:
#              index      eid  data_provider  issue_date   read_2  \
# 0             2618  1000421              3  08/12/2006      NaN
# 1             2619  1000421              3  11/01/2007      NaN
# 2             2620  1000421              3  02/02/2007      NaN
# 3             2621  1000421              3  02/02/2007      NaN
# 4             2622  1000421              3  04/05/2007      NaN
# ...            ...      ...            ...         ...      ...
# 17036262  57706536  6025040              1  05/06/2017  bxi3.00
# 17036263  57706537  6025040              1  05/06/2017  d711.00
# 17036264  57706538  6025040              1  05/06/2017  d711.00
# 17036265  57706539  6025040              1  05/06/2017  in45.00
# 17036266  57706540  6025040              1  05/06/2017  in45.00
#
#                 bnf_code     dmd_code  \
# 0         04.07.01.02.00          NaN
# 1         04.07.01.02.00          NaN
# 2         04.07.02.00.00          NaN
# 3         10.01.01.00.00          NaN
# 4         04.07.02.00.00          NaN
# ...                  ...          ...
# 17036262             NaN  320031002.0
# 17036263             NaN  321745007.0
# 17036264             NaN  321745007.0
# 17036265             NaN  329266003.0
# 17036266             NaN  329266003.0
#
#                                                 drug_name quantity
# 0                           Co-codamol 30mg/500mg tablets  100 tab
# 1                           Co-codamol 30mg/500mg tablets  100 tab
# 2                                  Tramadol 50mg capsules  100 cap
# 3         Diclofenac sodium 50mg gastro-resistant tablets   84 tab
# 4                                  Tramadol 50mg capsules  100 cap
# ...                                                   ...      ...
# 17036262                        Atorvastatin 40mg tablets   56.000
# 17036263                       Amitriptyline 10mg tablets   56.000
# 17036264                       Amitriptyline 10mg tablets   56.000
# 17036265                           Thiamine 100mg tablets   56.000
# 17036266                           Thiamine 100mg tablets   56.000
#
# [17036267 rows x 9 columns]

# %%
relevant_scripts[relevant_scripts['drug_name'].str.contains('aspirin') == True]
# Out:
#              index      eid  data_provider  issue_date   read_2 bnf_code  \
# 345374     1151113  1100490              1  16/10/2009  bu2B.00      NaN
# 345379     1151118  1100490              1  05/11/2009  bu23.00      NaN
# 345382     1151121  1100490              1  04/12/2009  bu2B.00      NaN
# 345393     1151132  1100490              1  01/07/2010  bu2B.00      NaN
# 345398     1151137  1100490              1  31/08/2010  bu2B.00      NaN
# ...            ...      ...            ...         ...      ...      ...
# 15986426  54216881  5726070              1  01/08/2007  bu23.00      NaN
# 16150908  54794247  5778574              1  02/11/1999  di1c.00      NaN
# 16150915  54794254  5778574              1  10/01/2000  di1c.00      NaN
# 16633077  56347804  5912906              1  19/01/2000  bu2A.00      NaN
# 16633143  56347870  5912906              1  08/10/2001  bu2A.00      NaN
#
#               dmd_code                                          drug_name  \
# 345374    3.197810e+08                aspirin enteric coated tablets 75mg
# 345379    3.197730e+08                    aspirin dispersible tablet 75mg
# 345382    3.197810e+08                aspirin enteric coated tablets 75mg
# 345393    3.197810e+08                aspirin enteric coated tablets 75mg
# 345398    3.197810e+08                aspirin enteric coated tablets 75mg
# ...                ...                                                ...
# 15986426  3.197730e+08                    aspirin dispersible tablet 75mg
# 16150908  2.211500e+16  Nu-seals aspirin ec 300mg Gastro-resistant tab...
# 16150915  2.211500e+16  Nu-seals aspirin ec 300mg Gastro-resistant tab...
# 16633077  2.213500e+16  Nu-seals aspirin ec 75mg Gastro-resistant tabl...
# 16633143  2.213500e+16  Nu-seals aspirin ec 75mg Gastro-resistant tabl...
#
#          quantity
# 345374    100.000
# 345379    100.000
# 345382     56.000
# 345393     56.000
# 345398     56.000
# ...           ...
# 15986426   28.000
# 16150908  100.000
# 16150915  112.000
# 16633077  100.000
# 16633143  100.000
#
# [191 rows x 9 columns]

# %%
relevant_scripts.sort_values('bnf_code')
# Out:
#              index      eid  data_provider  issue_date   read_2  \
# 6868583   23478594  3063971              3  28/10/1992      NaN
# 13696685  46555439  5066755              3  28/01/1997      NaN
# 12416763  42167298  4685852              3  13/08/2010      NaN
# 12416762  42167297  4685852              3  13/08/2010      NaN
# 478709     1590505  1140525              3  02/06/1992      NaN
# ...            ...      ...            ...         ...      ...
# 17036262  57706536  6025040              1  05/06/2017  bxi3.00
# 17036263  57706537  6025040              1  05/06/2017  d711.00
# 17036264  57706538  6025040              1  05/06/2017  d711.00
# 17036265  57706539  6025040              1  05/06/2017  in45.00
# 17036266  57706540  6025040              1  05/06/2017  in45.00
#
#                 bnf_code     dmd_code                               drug_name  \
# 6868583   01.01.01.01.00          NaN      Maalox TC tablets (Aventis Pharma)
# 13696685  01.01.01.01.00          NaN  Magnesium trisilicate compound tablets
# 12416763  01.01.01.01.00          NaN   Magnesium trisilicate oral suspension
# 12416762  01.01.01.01.00          NaN   Magnesium trisilicate oral suspension
# 478709    01.01.01.01.00          NaN   Magnesium trisilicate oral suspension
# ...                  ...          ...                                     ...
# 17036262             NaN  320031002.0               Atorvastatin 40mg tablets
# 17036263             NaN  321745007.0              Amitriptyline 10mg tablets
# 17036264             NaN  321745007.0              Amitriptyline 10mg tablets
# 17036265             NaN  329266003.0                  Thiamine 100mg tablets
# 17036266             NaN  329266003.0                  Thiamine 100mg tablets
#
#                    quantity
# 6868583                 100
# 13696685           100 tabs
# 12416763  1 pack of 200 mls
# 12416762  1 pack of 200 mls
# 478709               500 ml
# ...                     ...
# 17036262             56.000
# 17036263             56.000
# 17036264             56.000
# 17036265             56.000
# 17036266             56.000
#
# [17036267 rows x 9 columns]

# %%
relevant_scripts.sort_values('dmd_code')
# Out:
#              index      eid  data_provider  issue_date read_2 bnf_code  \
# 13930373  47230525  5124209              1  24/09/1999    NaN      NaN
# 5225499   17913599  2577573              1  01/03/1988    NaN      NaN
# 6007442   20577649  2811204              1  24/04/1990    NaN      NaN
# 15843853  53719707  5683940              1  14/03/1990    NaN      NaN
# 5367616   18349418  2613127              1  31/01/1989    NaN      NaN
# ...            ...      ...            ...         ...    ...      ...
# 17035366  57705640  6025023              4  25/08/2017  bl8i.      NaN
# 17035367  57705641  6025023              4  15/09/2017  ei15.      NaN
# 17035368  57705642  6025023              4  15/09/2017  ei15.      NaN
# 17035369  57705643  6025023              4  15/09/2017  ka83.      NaN
# 17035370  57705644  6025023              4  15/09/2017  ka83.      NaN
#
#           dmd_code                 drug_name quantity
# 13930373       0.0             HEPATYRIX VAC    1.000
# 5225499        0.0  POTASSIUM PERMANGANA SOL  500.000
# 6007442        0.0  LOCORTEN-VIOFORM EAR SOL    1.000
# 15843853       0.0      TUBIGRIP SIZE E (8.7    2.000
# 5367616        0.0      GAUZE DRESSING- BACT    2.000
# ...            ...                       ...      ...
# 17035366       NaN                       NaN      NaN
# 17035367       NaN                       NaN      NaN
# 17035368       NaN                       NaN      NaN
# 17035369       NaN                       NaN      NaN
# 17035370       NaN                       NaN      NaN
#
# [17036267 rows x 9 columns]

# %%
relevant_scripts.sort_values('bnf_code').tail(100)
# Out:
#              index      eid  data_provider  issue_date   read_2 bnf_code  \
# 17036167  57706441  6025040              1  10/08/2015  in45.00      NaN
# 17036168  57706442  6025040              1  10/08/2015  in72.00      NaN
# 17036169  57706443  6025040              1  17/08/2015  a6b5.00      NaN
# 17036170  57706444  6025040              1  17/08/2015  bd11.00      NaN
# 17036171  57706445  6025040              1  17/08/2015  bxi3.00      NaN
# ...            ...      ...            ...         ...      ...      ...
# 17036262  57706536  6025040              1  05/06/2017  bxi3.00      NaN
# 17036263  57706537  6025040              1  05/06/2017  d711.00      NaN
# 17036264  57706538  6025040              1  05/06/2017  d711.00      NaN
# 17036265  57706539  6025040              1  05/06/2017  in45.00      NaN
# 17036266  57706540  6025040              1  05/06/2017  in45.00      NaN
#
#              dmd_code                                  drug_name quantity
# 17036167  329266003.0                     Thiamine 100mg tablets   56.000
# 17036168  329298009.0          Vitamin B compound strong tablets  112.000
# 17036169  317295004.0  Omeprazole 40mg gastro-resistant capsules   56.000
# 17036170  318352004.0                   Propranolol 10mg tablets  112.000
# 17036171  320031002.0                  Atorvastatin 40mg tablets   56.000
# ...               ...                                        ...      ...
# 17036262  320031002.0                  Atorvastatin 40mg tablets   56.000
# 17036263  321745007.0                 Amitriptyline 10mg tablets   56.000
# 17036264  321745007.0                 Amitriptyline 10mg tablets   56.000
# 17036265  329266003.0                     Thiamine 100mg tablets   56.000
# 17036266  329266003.0                     Thiamine 100mg tablets   56.000
#
# [100 rows x 9 columns]

# %%
concise_scripts
# Out:
#               eid   read_2        bnf_code     dmd_code  \
# 0         1000421      NaN  04.07.01.02.00          NaN
# 1         1000421      NaN  04.07.01.02.00          NaN
# 2         1000421      NaN  04.07.02.00.00          NaN
# 3         1000421      NaN  10.01.01.00.00          NaN
# 4         1000421      NaN  04.07.02.00.00          NaN
# ...           ...      ...             ...          ...
# 17036262  6025040  bxi3.00             NaN  320031002.0
# 17036263  6025040  d711.00             NaN  321745007.0
# 17036264  6025040  d711.00             NaN  321745007.0
# 17036265  6025040  in45.00             NaN  329266003.0
# 17036266  6025040  in45.00             NaN  329266003.0
#
#                                                 drug_name quantity
# 0                           co-codamol 30mg/500mg tablets  100 tab
# 1                           co-codamol 30mg/500mg tablets  100 tab
# 2                                  tramadol 50mg capsules  100 cap
# 3         diclofenac sodium 50mg gastro-resistant tablets   84 tab
# 4                                  tramadol 50mg capsules  100 cap
# ...                                                   ...      ...
# 17036262                        atorvastatin 40mg tablets   56.000
# 17036263                       amitriptyline 10mg tablets   56.000
# 17036264                       amitriptyline 10mg tablets   56.000
# 17036265                           thiamine 100mg tablets   56.000
# 17036266                           thiamine 100mg tablets   56.000
#
# [17036267 rows x 6 columns]

# %%
drug_name_counts = concise_scripts.groupby('drug_name').count()['eid'].reset_index()

# %%
concise_scripts = concise_scripts.drop_duplicates('drug_name')

# %%
drug_name_counts.columns = ['drug_name', 'counts']

# %%
drug_name_counts.counts
# Out:
# 0          1
# 1          3
# 2          1
# 3          2
# 4          1
#         ...
# 37679      9
# 37680     32
# 37681    137
# 37682      8
# 37683      2
# Name: counts, Length: 37684, dtype: int64

# %%
unknown_meds = relevant_scripts[relevant_scripts['drug_name'].isnull() == True]

# %%
unknown_medsdf = unknown_meds.groupby('read_2').count().drop('index', axis = 1).reset_index()

# %%
unknown_medications = unknown_medsdf[['read_2', 'eid']]

# %%
unknown_medications.columns = ['read_2', 'count']

# %%
unknown_medications
# Out:
#      read_2  count
# 0     a116.     35
# 1     a123.    250
# 2     a124.      6
# 3     a125.     75
# 4     a134.    110
# ...     ...    ...
# 6483  sn2q.     11
# 6484  sn2t.     13
# 6485  so24.    105
# 6486  so26.      2
# 6487  so29.      1
#
# [6488 rows x 2 columns]

# %%
concise_scripts['name'] = [x.split(' ')[0] if type(x) == str else np.nan for x in concise_scripts['drug_name']]
# Out:
# /Users/michelleng/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
bnf_scripts = concise_scripts[concise_scripts['bnf_code'].isnull() == False].sort_values('bnf_code').reset_index()

# %%
drug_name_counts.describe()
# Out:
#               counts
# count   37684.000000
# mean      393.702632
# std      5902.766805
# min         1.000000
# 25%         2.000000
# 50%         8.000000
# 75%        45.000000
# max    593035.000000

# %%
bnf = pd.merge(bnf_scripts[['bnf_code', 'drug_name', 'name']], drug_name_counts, on='drug_name', how = "left")

# %%
bnf
# Out:
#              bnf_code                                          drug_name  \
# 0      01.01.01.01.00             aluminium hydroxide mixture sugar-free
# 1      01.01.01.01.00                 aluminium hydroxide 475mg capsules
# 2      01.01.01.01.00                   co-magaldrox 300mg/600mg tablets
# 3      01.01.01.01.00                 maalox tc tablets (aventis pharma)
# 4      01.01.01.01.00  co-magaldrox 300mg/600mg/5ml oral suspension s...
# ...               ...                                                ...
# 22968          A70601  glutafin select gluten-free  part-baked white ...
# 22969        A7060101  glutafin gluten-free wheat free  multipurpose ...
# 22970        A7060101  glutafin rolls gluten free wheat free fibre 4 ...
# 22971        A7060101      glutafin gluten-free  crisp breads  150 grams
# 22972          A70602                juvela loaf low protein sliced 400g
#
#                name  counts
# 0         aluminium      15
# 1         aluminium      30
# 2      co-magaldrox       1
# 3            maalox       8
# 4      co-magaldrox      16
# ...             ...     ...
# 22968      glutafin      23
# 22969      glutafin       5
# 22970      glutafin       1
# 22971      glutafin       8
# 22972        juvela       1
#
# [22973 rows x 4 columns]

# %%
dmd_scripts = concise_scripts[concise_scripts['dmd_code'].isnull() == False].sort_values('dmd_code').reset_index()

# %%
dmd = pd.merge(dmd_scripts[['dmd_code', 'drug_name', 'name']], drug_name_counts, on='drug_name', how = "left")

# %%
concise = pd.merge(concise_scripts[['drug_name', 'dmd_code', 'read_2', 'bnf_code', 'name']], drug_name_counts, on='drug_name', how = "left")

# %%
with pd.ExcelWriter('../primary_care/medications.xlsx') as writer:  
    concise.to_excel(writer, sheet_name='all_unique_names')
    unknown_medications.to_excel(writer, sheet_name='unknown medications')
    bnf.to_excel(writer, sheet_name='bnf_codes')
    dmd.to_excel(writer, sheet_name='dmd_codes')

# %%
records
# Out:
#            eid                                              coded  \
# 0      1000255                           [[02/09/2015, cad, sec]]
# 1      1000421  [[04/08/2010, cad, sec], [27/05/2010, stroke, ...
# 2      1000466                           [[11/06/2002, cad, sec]]
# 3      1000584  [[16/06/1997, cad, sec], [19/10/2004, afib, sec]]
# 4      1000674                           [[31/05/2006, cad, sec]]
# ...        ...                                                ...
# 53318  6020725                                                 []
# 53319  6021009                                                 []
# 53320  6021143                                                 []
# 53321  6022795                                                 []
# 53322  6023090                                                 []
#
#                                            data_provider  \
# 0                                                    NaN
# 1                                                 [3, 3]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                                             [3, 3]
# 53319                                                [3]
# 53320  [3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, ...
# 53321                                                [2]
# 53322                                                [3]
#
#                                                 event_dt  \
# 0                                                    NaN
# 1                               [27/05/2010, 04/10/2010]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                           [01/01/1993, 18/09/2003]
# 53319                                       [09/06/2016]
# 53320  [20/01/2005, 11/02/2005, 07/04/2005, 21/11/200...
# 53321                                       [19/01/2015]
# 53322                                       [29/07/2005]
#
#                                                   read_2  \
# 0                                                    NaN
# 1                                             [nan, nan]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                                         [nan, nan]
# 53319                                              [nan]
# 53320  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 53321                                            [G5730]
# 53322                                              [nan]
#
#                                                   read_3  \
# 0                                                    NaN
# 1                                         [XE0VK, XE2uV]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                                     [G66.., XE0VK]
# 53319                                            [G5730]
# 53320  [X00DW, X00DW, X00DW, X00DW, X00DW, X00DW, X00...
# 53321                                              [nan]
# 53322                                            [XE2uV]
#
#                                                   value1  \
# 0                                                    NaN
# 1                                             [nan, nan]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                                         [nan, nan]
# 53319                                              [nan]
# 53320  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 53321                                              [nan]
# 53322                                              [nan]
#
#                                                   value2  \
# 0                                                    NaN
# 1                                             [nan, nan]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                                         [nan, nan]
# 53319                                              [nan]
# 53320  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 53321                                              [nan]
# 53322                                              [nan]
#
#                                                   value3  \
# 0                                                    NaN
# 1                                             [nan, nan]
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 53318                                         [nan, nan]
# 53319                                              [nan]
# 53320  [nan, nan, nan, nan, nan, nan, nan, nan, nan, ...
# 53321                                              [nan]
# 53322                                              [nan]
#
#                                                condition  ... first_record_d  \
# 0                                                    NaN  ...     2015-09-02
# 1                                             [TIA, CAD]  ...     2010-05-27
# 2                                                    NaN  ...     2002-06-11
# 3                                                    NaN  ...     1997-06-16
# 4                                                    NaN  ...     2006-05-31
# ...                                                  ...  ...            ...
# 53318                                      [Stroke, TIA]  ...     1993-01-01
# 53319                                             [Afib]  ...     2016-06-09
# 53320  [TIA, TIA, TIA, TIA, TIA, TIA, TIA, TIA, TIA, ...  ...     2005-01-20
# 53321                                             [Afib]  ...     2015-01-19
# 53322                                              [CAD]  ...     2005-07-29
#
#       first_record_diag  first_stroke_after_d first_stroke_type  \
# 0                   cad                   NaT               NaN
# 1                   tia            2010-05-27            stroke
# 2                   cad                   NaT               NaN
# 3                   cad                   NaT               NaN
# 4                   cad                   NaT               NaN
# ...                 ...                   ...               ...
# 53318            stroke            2003-09-18               tia
# 53319              afib                   NaT               NaN
# 53320               tia            2005-02-11               tia
# 53321              afib                   NaT               NaN
# 53322               cad                   NaT               NaN
#
#                                                      pri  \
# 0                                                     []
# 1      [[2010-05-27 00:00:00, tia, pri], [2010-10-04 ...
# 2                                                     []
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 53318  [[1993-01-01 00:00:00, stroke, pri], [2003-09-...
# 53319                 [[2016-06-09 00:00:00, afib, pri]]
# 53320  [[2005-01-20 00:00:00, tia, pri], [2005-02-11 ...
# 53321                 [[2015-01-19 00:00:00, afib, pri]]
# 53322                  [[2005-07-29 00:00:00, cad, pri]]
#
#                                                      sec discrepancy  \
# 0                      [[2015-09-02 00:00:00, cad, sec]]       False
# 1      [[2010-05-27 00:00:00, stroke, sec], [2010-08-...       False
# 2                      [[2002-06-11 00:00:00, cad, sec]]       False
# 3      [[1997-06-16 00:00:00, cad, sec], [2004-10-19 ...       False
# 4                      [[2006-05-31 00:00:00, cad, sec]]       False
# ...                                                  ...         ...
# 53318                                                 []       False
# 53319                                                 []       False
# 53320                                                 []       False
# 53321                                                 []       False
# 53322                                                 []       False
#
#       noRecords noRecords2   event_int
# 0             1          1         NaN
# 1             4          4    0.000000
# 2             1          1         NaN
# 3             2          2         NaN
# 4             1          1         NaN
# ...         ...        ...         ...
# 53318         2          2  128.528307
# 53319         1          1         NaN
# 53320        19         19    0.722807
# 53321         1          1         NaN
# 53322         1          1         NaN
#
# [53323 rows x 27 columns]

# %%
bnf
# Out:
#              bnf_code                                          drug_name  \
# 0      01.01.01.01.00             aluminium hydroxide mixture sugar-free
# 1      01.01.01.01.00                 aluminium hydroxide 475mg capsules
# 2      01.01.01.01.00                   co-magaldrox 300mg/600mg tablets
# 3      01.01.01.01.00                 maalox tc tablets (aventis pharma)
# 4      01.01.01.01.00  co-magaldrox 300mg/600mg/5ml oral suspension s...
# ...               ...                                                ...
# 22968          A70601  glutafin select gluten-free  part-baked white ...
# 22969        A7060101  glutafin gluten-free wheat free  multipurpose ...
# 22970        A7060101  glutafin rolls gluten free wheat free fibre 4 ...
# 22971        A7060101      glutafin gluten-free  crisp breads  150 grams
# 22972          A70602                juvela loaf low protein sliced 400g
#
#                name  counts
# 0         aluminium      15
# 1         aluminium      30
# 2      co-magaldrox       1
# 3            maalox       8
# 4      co-magaldrox      16
# ...             ...     ...
# 22968      glutafin      23
# 22969      glutafin       5
# 22970      glutafin       1
# 22971      glutafin       8
# 22972        juvela       1
#
# [22973 rows x 4 columns]

# %%
bnf[bnf['bnf_code'].str[0:2] == '10']
# Out:
#              bnf_code                                          drug_name  \
# 12997  10.01.01.00.00          indometacin 25mg modified-release tablets
# 12998  10.01.01.00.00                 brexidol 20mg tablets (chiesi ltd)
# 12999  10.01.01.00.00      froben 50mg tablets (abbott laboratories ltd)
# 13000  10.01.01.00.00                          lumiracoxib 100mg tablets
# 13001  10.01.01.00.00                  indomax capsules 25mg [ashbourne]
# ...               ...                                                ...
# 13960        10030250           traxam 3% gel (mercury pharma group ltd)
# 13961        10030250                                  diclofenac 2% gel
# 13962        10030250  salicylic acid 2% / mucopolysaccharide polysul...
# 13963        10030250  voltarol 1% emulgel p (novartis consumer healt...
# 13964        10030250                  movelat gel (thornton & ross ltd)
#
#               name  counts
# 12997  indometacin       4
# 12998     brexidol      95
# 12999       froben      26
# 13000  lumiracoxib      32
# 13001      indomax      10
# ...            ...     ...
# 13960       traxam      13
# 13961   diclofenac       5
# 13962    salicylic      13
# 13963     voltarol      10
# 13964      movelat      23
#
# [968 rows x 4 columns]

# %%
bnf[:18575].groupby('bnf_code').sum().shape
# Out:
# (3168, 1)

# %%
bnf[:18575].groupby('bnf_code').sum()['counts'].sum()
# Out:
# 13476586

# %%
bnf[18575:].groupby('bnf_code').sum()['counts'].sum()
# Out:
# 172789

# %%
dmd['dmd_code_str'] = [str(int(x)) for x in dmd['dmd_code']]

# %%
dmd[dmd['dmd_code_str'] != 0].groupby('dmd_code_str').sum().shape
# Out:
# (6503, 2)

# %%
dmd[dmd['dmd_code_str'] != 0].groupby('dmd_code_str').sum()['counts'].sum()
# Out:
# 1174380

# %%
dmd[dmd['dmd_code_str'].str[0:2] == '24']
# Out:
#            dmd_code                                          drug_name  \
# 4675   2.401110e+14                       transiderm-nitro patches 5mg
# 4676   2.401110e+14                           transiderm-nitro 5 patch
# 4677   2.401110e+14  transiderm-nitro 5 transdermal patches (novart...
# 4678   2.402110e+14                                   nexium tabs 40mg
# 4679   2.413110e+14                                         vermox syr
# ...             ...                                                ...
# 12988  2.479050e+17        engerix b injection 20 micrograms/1 ml vial
# 12989  2.479050e+17                 engerix b vaccine 20micrograms/1ml
# 12990  2.484650e+17  polyureth foa light-med exud + adhe bor fil dr...
# 12991  2.496550e+17                    vicks sinex soother nasal spray
# 12992  2.499350e+17                              octenidine hcl lotion
#
#                    name  counts        dmd_code_str
# 4675   transiderm-nitro       6     240111000001101
# 4676   transiderm-nitro      21     240111000001101
# 4677   transiderm-nitro      18     240111000001101
# 4678             nexium      12     240211000001107
# 4679             vermox       1     241311000001109
# ...                 ...     ...                 ...
# 12988           engerix       4  247905001000027104
# 12989           engerix      35  247905001000027104
# 12990         polyureth       1  248465001000027104
# 12991             vicks       1  249655001000027104
# 12992        octenidine       1  249935001000027104
#
# [106 rows x 5 columns]

# %%
unknown_medications
# Out:
#      read_2  count
# 0     a116.     35
# 1     a123.    250
# 2     a124.      6
# 3     a125.     75
# 4     a134.    110
# ...     ...    ...
# 6483  sn2q.     11
# 6484  sn2t.     13
# 6485  so24.    105
# 6486  so26.      2
# 6487  so29.      1
#
# [6488 rows x 2 columns]
